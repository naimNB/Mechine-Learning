# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('/home/md-naim/My Workspace/Mechine-Learning/Logistic_Regression/advertising.xlsx')
data.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#             Timestamp  Clicked on Ad
# 0 2016-03-27 00:53:11              0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Ad Topic Line             1000 non-null   object
#  5   City                      1000 non-null   object
#  6   Male                      1000 non-null   int64
#  7   Country                   1000 non-null   object
#  8   Timestamp                 1000 non-null   datetime64[ns]
#  9   Clicked on Ad             1000 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(3)
# memory usage: 78.2+ KB

# %%
data['Ad Topic Line'].nunique() # unique value define unique,and, nuniq value kotogulo seita define kore
# Out:
# 1000

# %%
data['City'].nunique()
# Out:
# 969

# %%
data.drop(
    columns=['Ad Topic Line', 'City', 'Timestamp', 'Country'], 
    inplace=True
)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Male                      1000 non-null   int64
#  5   Clicked on Ad             1000 non-null   int64
# dtypes: float64(3), int64(3)
# memory usage: 47.0 KB

# %%
sns.boxplot(
    data=data,
    y='Daily Time Spent on Site',
    x='Clicked on Ad'
)
# Out:
# <Axes: xlabel='Clicked on Ad', ylabel='Daily Time Spent on Site'>

# %%
sns.jointplot(
    data=data,
    x='Daily Time Spent on Site',
    y='Age'
)

# %%
sns.jointplot(
    data=data,
    x='Daily Time Spent on Site',
    y='Age',
    kind='kde'
)

# %%
sns.jointplot(
    data=data,
    x='Daily Time Spent on Site',
    y='Age',
    kind='kde',
    fill=True
)
