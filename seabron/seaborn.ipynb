# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
data = sns.load_dataset('tips')
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
data['smoker'].unique()
# Out:
# ['No', 'Yes']
# Categories (2, object): ['Yes', 'No']

# %%
data['time'].unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
data['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
sns.histplot(data=data, x='total_bill', kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
bins=[0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50]
sns.histplot(data=data, x='total_bill',y='tip', bins=bins)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.jointplot(
    data = data, 
    x='total_bill', 
    y='tip',
    hue='day',
    
)

# %%
sns.jointplot(
    data = data, 
    x='total_bill', 
    y='tip',
    kind='hex'
)

# %%
sns.jointplot(
    data = data, 
    x='total_bill', 
    y='tip',
    kind='reg'
)

# %%
sns.jointplot(
    data = data, 
    x='total_bill', 
    y='tip',
    kind='kde'
)

# %%
sns.jointplot(
    data = data, 
    x='total_bill', 
    y='tip',
    kind='resid'
)

# %%
sns.jointplot(
    data = data, 
    x='total_bill', 
    y='tip',
    kind='scatter'
)

# %%
sns.pairplot(
    data = data,
)

# %%
sns.pairplot(
    data=data,
    kind='reg',
)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.pairplot(
    data=data,
    hue='day',
    palette='Dark2'
)

# %% [markdown]
# ### Karnal Density Estimation(KDE)

# %%
sns.histplot(
    data=data,
    x='tip',
    kde=True,
)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.rugplot(
    data=data,
    x='tip',
)
# Out:
# <Axes: xlabel='tip'>

# %%
sns.histplot(
    data=data,
    bins=[2,4,6,8,10,12,14],
    x='tip',
)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.kdeplot(
    data=data,
    x='tip'
)
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.countplot(
    data=data,
    x='day',
    
)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(
    data=data,
    x='day',
    hue='sex',
)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
import numpy as np
ax=sns.barplot(
    data=data,
    x='day',
    y='total_bill',
    estimator=np.sum,
)
ax.set_xlabel('axes of x label')
# Out:
# Text(0.5, 0, 'axes of x label')

# %% [markdown]
# #### Boxplot

# %%
sns.boxplot(data=data, x='day', y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(
    data=data,
    x='day',
    y='total_bill',
    hue='smoker',
)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(
    data=data,
    x='day',
    y='total_bill',
    hue='smoker',
    split=True
)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(
    data=data,
    x='day',
    y='total_bill'
)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(
    data=data,
    x='day',
    y='total_bill'
)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(
    data=data,
    x='day',
    y='total_bill'
)
sns.violinplot(
    data=data,
    x='day',
    y='total_bill'
)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(
    data=data,
    x='day',
    y='total_bill',
    kind='violin'
)

# %%
sns.catplot(
    data=data,
    x='day',
    y='total_bill',
    kind='bar'
)

# %%
sns.catplot(
    data=data,
    x='day',
    y='total_bill',
    kind='point'
)

# %%
sns.catplot(
    data=data,
    x='day',
    y='total_bill',
    kind='strip'
)

# %% [markdown]
# ## Heat Map
#
# - find corellation

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
corr = data.corr(numeric_only=True)

# %% [markdown]
# - annot = True means show the value of heatmap

# %%
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# * using flights dataset
# - this dataset load into sns dataset and using sns.load_dataset('____')

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %% [markdown]
# - represent into pivot table into numericee ad catagorical table

# %%
pivot = flights.pivot_table(
    index='month',
    columns='year',
    values='passengers'
)
# Out:
# /tmp/ipykernel_13934/3268313117.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot = flights.pivot_table(

# %%
sns.heatmap(pivot,cmap='coolwarm', linecolor='white', linewidths=1)
# Out:
# <Axes: xlabel='year', ylabel='month'>
